# %% [markdown]
# # Eniac —the e-commerce

# %% [markdown]
# The company has high hopes put into the possibilities that come with Data Analysis, and they are especially hopeful that your work can finally settle an ongoing debate: whether or not it’s beneficial to discount products.
#
# * The Marketing Team Lead is convinced that offering discounts is beneficial in the long run. She believes discounts improve customer acquisition, satisfaction and retention, and allow the company to grow.
# * The main investors in the Board are worried about offering aggressive discounts. They have pointed out how the company’s recent quarterly results showed an increase in orders placed, but a decrease in the total revenue. They prefer that the company positions itself in the quality segment, rather than competing to offer the lowest prices in the market.

# %%
# %pip install pandas numpy
# Out:
# Requirement already satisfied: pandas in d:\study\wbs coing school\bootcamp\bootcamp\eniac_2\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in d:\study\wbs coing school\bootcamp\bootcamp\eniac_2\.venv\lib\site-packages (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\study\wbs coing school\bootcamp\bootcamp\eniac_2\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\study\wbs coing school\bootcamp\bootcamp\eniac_2\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\study\wbs coing school\bootcamp\bootcamp\eniac_2\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\study\wbs coing school\bootcamp\bootcamp\eniac_2\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load necessary libraries and datasets

# %%
import pandas as pd
import numpy as np 
import math

brands_df = pd.read_csv("./Datasets/brands.csv")
orderlines_df = pd.read_csv("./Datasets/orderlines.csv")
orders_df = pd.read_csv("./Datasets/orders.csv")
products_df = pd.read_csv("./Datasets/products.csv")

# %% [markdown]
# ## First glance and task statements

# %% [markdown]
# ### Brands

# %%
brands_df.info(), 
brands_df.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   short   187 non-null    object
#  1   long    187 non-null    object
# dtypes: object(2)
# memory usage: 3.1+ KB
# np.int64(0)

# %% [markdown]
# Clear 0 duplicates/ 0 null shape(187,2)

# %% [markdown]
# ### Orderlines

# %%
orderlines_df.info() 
orderlines_df.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        293983 non-null  object
#  6   date              293983 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 15.7+ MB
# np.int64(0)

# %%
orderlines_df.head()
# Out:
#         id  id_order  product_id  product_quantity      sku unit_price  \
# 0  1119109    299539           0                 1  OTT0133      18.99
# 1  1119110    299540           0                 1  LGE0043     399.00
# 2  1119111    299541           0                 1  PAR0071     474.05
# 3  1119112    299542           0                 1  WDT0315      68.39
# 4  1119113    299543           0                 1  JBL0104      23.74
#
#                   date
# 0  2017-01-01 00:07:19
# 1  2017-01-01 00:19:45
# 2  2017-01-01 00:20:57
# 3  2017-01-01 00:51:40
# 4  2017-01-01 01:06:38

# %%
orderlines_df.describe()
# Out:
#                  id       id_order  product_id  product_quantity
# count  2.939830e+05  293983.000000    293983.0     293983.000000
# mean   1.397918e+06  419999.116544         0.0          1.121126
# std    1.530096e+05   66344.486479         0.0          3.396569
# min    1.119109e+06  241319.000000         0.0          1.000000
# 25%    1.262542e+06  362258.500000         0.0          1.000000
# 50%    1.406940e+06  425956.000000         0.0          1.000000
# 75%    1.531322e+06  478657.000000         0.0          1.000000
# max    1.650203e+06  527401.000000         0.0        999.000000

# %% [markdown]
# ### Orderlines_df tasks
# We need to:
# * drop product_id - all nulls
# * convert unit_price to float
# * convert date from object to date

# %% [markdown]
# ### Orders

# %%
orders_df.info() 
orders_df.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226909 entries, 0 to 226908
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      226909 non-null  int64
#  1   created_date  226909 non-null  object
#  2   total_paid    226904 non-null  float64
#  3   state         226909 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.9+ MB
# np.int64(0)

# %%
orders_df['total_paid'].isna().value_counts()
# Out:
# total_paid
# False    226904
# True          5
# Name: count, dtype: int64

# %%
orders_df.head()
# Out:
#    order_id         created_date  total_paid      state
# 0    241319  2017-01-02 13:35:40       44.99  Cancelled
# 1    241423  2017-11-06 13:10:02      136.15  Completed
# 2    242832  2017-12-31 17:40:03       15.76  Completed
# 3    243330  2017-02-16 10:59:38       84.98  Completed
# 4    243784  2017-11-24 13:35:19      157.86  Cancelled

# %% [markdown]
# ### Orders_df tasks
# We need to:
#
# * convert date from object to date
# * delete all null values in total_paid columns

# %% [markdown]
# ### Products

# %%
products_df.info() 
products_df.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        19280 non-null  object
#  4   promo_price  19326 non-null  object
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB
# np.int64(8746)

# %%
products_df.describe()
# Out:
#            in_stock
# count  19326.000000
# mean       0.109593
# std        0.312390
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
products_df.sample(10)
# Out:
#              sku                                               name  \
# 12730    PAC1457          WD My Cloud EX4100 Pack | WD 16TB Network
# 13848    APP1851  Apple MacBook Pro 13 "Core i5 with Touch Bar 3...
# 15120  SAT0010-A  Open - Satechi Sonic Dual Conical Mac v2.0 Spe...
# 8325     PAC0930  Apple iMac 27 "Core i5 3.2GHz Retina 5K | 16GB...
# 6477     PAC1070  Apple iMac 27 "Core i5 3.3GHz Retina 5K | 32GB...
# 17086  WAC0236-A      Open - Education - A4 Wacom Bamboo Slate Gray
# 10131    PAC1591  Apple iMac 27 "Core i5 3.2GHz Retina 5K | RAM ...
# 16260    PAC2119  Apple iMac 27 "Core i7 Retina 5K 42GHz | 32GB ...
# 4141     APP1389  Apple iMac 27 "Core i5 3.3GHz Retina 5K | 8GB ...
# 15857    DRO0030                    5N2 Drobo NAS server Mac and PC
#
#                                                     desc   price promo_price  \
# 12730  WD My Cloud EX4100 + 16TB (4x4TB) Network WD H...    1275   9.629.906
# 13848  New MacBook Pro 13-inch Core i5 Touch Bar to 3...    2799   2.665.584
# 15120  Speakers matte finish sleek design and volume ...   39.99     263.913
# 8325   IMac desktop computer 27 inch Retina 5K RAM 16...    2849  25.759.896
# 6477   IMac desktop computer 27 inch 5K Retina i5 3.3...    4369  37.659.895
# 17086  Smart Bloc notes A4 size reconditioned app inc...  149.99     966.599
# 10131  Desktop computer iMac 27-inch 3.2GHz Core i5 5...    3409  27.249.902
# 16260  IMac desktop computer 27 inch Retina 5K RAM 32...    3799  33.750.045
# 4141   IMac desktop computer 27 inch 8GB RAM 512GB Re...    3169  30.175.839
# 15857  5-bay NAS server with two Gigabit Ethernet por...     689      482.99
#
#        in_stock      type
# 12730         0  11935397
# 13848         0      2158
# 15120         0      1298
# 8325          0      1282
# 6477          0  5,74E+15
# 17086         0      1298
# 10131         0  5,74E+15
# 16260         0  5,74E+15
# 4141          0  5,74E+15
# 15857         0      1280

# %%
products_df.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                 desc  price promo_price  \
# 0       Aluminum support compatible with all MacBook  59.99     499.899
# 1          USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                             mouse Apple USB cable.     59     569.898
# 3              IPhone dock and USB Cable Apple iPod.     25     229.997
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
#
#    in_stock      type
# 0         1      8696
# 1         0  13855401
# 2         0      1387
# 3         0      1230
# 4         1      1364

# %% [markdown]
# ### Products_df tasks
# We need to:
#
# * drop 8746 duplicates
# * solve problem with additional dots in price and promo_price columns
# * convert price and promo_price
# * deside what to do with in_stock columns
